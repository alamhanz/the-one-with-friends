# %% [markdown]
# # Late EDA

# %%
import pandas as pd
import re
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial import distance_matrix

# %%
PATH_DATA = '../data/'

# %% [markdown]
# ## Data Import

# %%
df_dlg = pd.read_csv(PATH_DATA+'friends_all_dialogue_semi_cln2.csv')

# %% [markdown]
# ## Creating Label

# %% [markdown]
# Take care of places

# %%
place_dlg_cnt = df_dlg.scenes_places.value_counts()
place_dlg_cnt[place_dlg_cnt>200].sort_values(ascending=False).index.tolist()
place_dict = {'[central perk]': 1,
 "[monica and rachel's]":2,
 "[monica and chandler's]":2,
 "[chandler and joey's]":3,
 "[joey and rachel's]":3,
 '[monica]':2,
 "[monica and rachel's apartment]":2,
 "[monica and chandler's apartment]":2,
 "[ross's apartment]":4,
 "[monica's apartment]":2,
 "[joey's apartment]":3,
 '[unknown]':0,
 '[the hallway]':5,
 "[monica and rachel's erm]":2,
 '[a restaurant]':6,
 "[joey and rachel's apartment]":3,
 "[chandler and joey's apartment]":3,
 "[rachel's office]":7,
 '[the hospital]':8,
 '[chandler]':3,
 "[phoebe's apartment]":9,
 "[chandler's office]":10,
 "[ross and rachel's]":4,
 '[a street]':0,
 "[at chandler and joey's]":3,
 '[central perk]]':1,
 '[the delivery room]':8,
 "[at monica and rachel's]":2,
 "[monica's bedroom]":2,
 "[monica and phoebe's]":2,
 "[ross and rachel's apartment]":4,
 "[monica and chandler's bedroom]":2,
 "[rachel's room]":2,
 '[the beach house]':0,
 '[outside central perk]':0,
 '[silvercup studios]':11,
 '[the park]':0,
 "[chandler and joey's erm]":3,
 "[phoebe and rachel's]":9,
 '[barbados]':0,
 "[carol and susan's]":0,
 '[mr]':0,
 '[the theatre]':0,
 '[the semi private labor room]':8,
 "[rachel's bedroom]":2,
 "[i'm surprised that rachel and ross didn't say they weren't either here]]":0,
 "[chandler and monica's]":2,
 "[bloomingdale's]":7,
 "[chandler and monica's apartment]":2,
 '[the hallway between the apartments]':5,
 '[the rest stop]':6,
 '[the restaurant]':6,
 "[monica and chandler's apartment]]":2,
 '[the anniversary party]':0,
 "[phoebe's cab]":0,
 '[monica and chandlers apartment]':2,
 "[monica and rachel's balcony]":2,
 '[later on in the hallway between the apartments]':5,
 '[the roof]':0,
 '[the waiting room]':0,
 '[continued from earlier]':0,
 '[dr]':0,
 '[the airport]':0,
 "[chandler and monica's apartment]]":2,
 '[the moondance diner]':6,
             
 '[the charity event]':0,
 "[joey and janine's]":3,
 "[chandler and eddie's apartment]":3,
 "[rachel's old room]":2,
 '[restaurant]':6,
 "[ross' apartment]":4,
 "[monica's restaurant kitchen]":12,
 '[the reception hall]':0,
 '[the porsche]':0,
 "[joanna's office]":7,
 "[monica and chandler's new apartment]":2,
 '[the movie set]':11,
 "[joey's apartment]]":3,
 "[chandler's apartment]":3,
 '[central park]':1,
 '[the bar]':0,
 "[rachel and joey's apartment]]":3,
 "[chandler and monica's]]":2,
 "[rachel and monica's]":2,
 '[the street in front of central perk]':0,
 '[the recovery room]':8}

# %%
df_dlg['label_place'] = df_dlg.scenes_places.apply(lambda x : place_dict[x] if x in list(place_dict.keys()) 
                                                   else 0)
df_dlg['label_place'].value_counts()
# Out:
# 2     18980
# 0     18883
# 1     10512
# 3      6812
# 4      1704
# 6       991
# 5       867
# 8       862
# 7       673
# 9       505
# 10      328
# 11      278
# 12       95
# Name: label_place, dtype: int64

# %%
# place_dlg_cnt = df_dlg[df_dlg.label_place == -1].scenes_places.value_counts()
# place_dlg_cnt[place_dlg_cnt>50].sort_values(ascending=False).index.tolist()

# %%
# char_dlg_cnt = df_dlg.character.value_counts()
# char_dlg_cnt[char_dlg_cnt>100].index.tolist()
char = ['rachel', 'ross', 'monica', 'chandler', 'joey', 'phoebe']
char_id = [1,2,3,4,5,6]
char2id = dict(zip(char+['other'],char_id+[0]))

# %%
df_dlg['label_str'] = df_dlg.character.apply(lambda x : x if x in char else 'other')
df_dlg['label'] = df_dlg.label_str.apply(lambda x : char2id[x])

# %%
df_dlg.head(10)
# Out:
#     eps  dialogue_ids   scenes_places character  \
# 0  0101             0  [central perk]    monica
# 1  0101             1  [central perk]      joey
# 2  0101             2  [central perk]  chandler
# 3  0101             3  [central perk]    phoebe
# 4  0101             4  [central perk]    phoebe
# 5  0101             5  [central perk]    monica
# 6  0101             6  [central perk]  chandler
# 7  0101             7  [central perk]  chandler
# 8  0101             8  [central perk]       all
# 9  0101             9  [central perk]  chandler
#
#                                             dialogue  \
# 0    there's nothing to tell! he's just some guy ...
# 1    c'mon, you're going out with the guy! there'...
# 2     all right joey, be nice.  so does he have a...
# 3    wait, does he eat chalk? (they all stare, be...
# 4    just, 'cause, i don't want her to go through...
# 5    okay, everybody relax. this is not even a da...
# 6             sounds like a date to me. [time lapse]
# 7    alright, so i'm back in high school, i'm sta...
# 8                          oh, yeah. had that dream.
# 9    then i look down, and i realize there's a ph...
#
#                                            dialogue2  \
# 0    there's nothing to tell! he's just some guy ...
# 1    c'mon, you're going out with the guy! there'...
# 2     all right joey, be nice.  so does he have a...
# 3                          wait, does he eat chalk?
# 4    just, 'cause, i don't want her to go through...
# 5    okay, everybody relax. this is not even a da...
# 6                         sounds like a date to me.
# 7    alright, so i'm back in high school, i'm sta...
# 8                          oh, yeah. had that dream.
# 9    then i look down, and i realize there's a ph...
#
#                                            dialogue3  \
# 0  there's nothing to tell he's just some guy i w...
# 1  c'mon you're going out with the guy there's go...
# 2  all right joey be nice so does he have a hump ...
# 3                             wait does he eat chalk
# 4  just because i don't want her to go through wh...
# 5  okay everybody relax this is not even a date i...
# 6                           sounds like a date to me
# 7  alright so i'm back in high school i'm standin...
# 8                             oh yeah had that dream
# 9  then i look down and i realize there's a phone...
#
#                                            dialogue4  label_place label_str  \
# 0  there has nothing to tell he has just some guy...            1    monica
# 1  come on you are going out with the guy there h...            1      joey
# 2  all right joey be nice so does he have a hump ...            1  chandler
# 3                             wait does he eat chalk            1    phoebe
# 4  just because i do not want her to go through w...            1    phoebe
# 5  okay everybody relax this is not even a date i...            1    monica
# 6                           sounds like a date to me            1  chandler
# 7  alright so i am back in high school i am stand...            1  chandler
# 8                             oh yeah had that dream            1     other
# 9  then i look down and i realize there has a pho...            1  chandler
#
#    label
# 0      3
# 1      5
# 2      4
# 3      6
# 4      6
# 5      3
# 6      4
# 7      4
# 8      0
# 9      4

# %%
dlg_cnt = df_dlg.label_str.value_counts()
dlg_cnt
# Out:
# other       10797
# rachel       9248
# ross         9055
# monica       8383
# chandler     8355
# joey         8176
# phoebe       7476
# Name: label_str, dtype: int64

# %%
# df_dlg[(df_dlg.dialogue3.isnull())]

# %%
df_dlg['season']= df_dlg['eps'].apply(lambda x : x[:2])
df_dlg.season.unique()
# Out:
# array(['01', '02', '03', '04', '05', '06', '07', '08', '09', '10'],
#       dtype=object)

# %%
# df_dlg = df_dlg[~(df_dlg.dialogue3.isnull())]
df_dlg['is_null'] = df_dlg.dialogue4.isnull()

# %% [markdown]
# ## Null data

# %%
df_dlg.groupby('label_str').is_null.mean()
# Out:
# label_str
# chandler    0.000359
# joey        0.001101
# monica      0.004056
# other       0.004909
# phoebe      0.000669
# rachel      0.000973
# ross        0.000552
# Name: is_null, dtype: float64

# %% [markdown]
# ## Sentence Length

# %%
df_dlg.dialogue4 = df_dlg.dialogue4.fillna('')
df_dlg.dialogue4 = df_dlg.dialogue4.str.strip()
df_dlg['len_dialogue4'] = df_dlg.dialogue4.str.split().apply(lambda x : len(x))

df_dlg.dialogue3 = df_dlg.dialogue3.fillna('')
df_dlg.dialogue3 = df_dlg.dialogue3.str.strip()
df_dlg['len_dialogue3'] = df_dlg.dialogue3.str.split().apply(lambda x : len(x))

# %%
df_dlg[df_dlg['len_dialogue4']==1].sample(10)
# Out:
#         eps  dialogue_ids                    scenes_places  character  \
# 40368  0713           274                  [earl's office]       earl
# 12453  0303           146            [monica and rachel's]       ross
# 6812   0204           187               [ross's apartment]     rachel
# 35317  0619           180                   [central perk]  sebastian
# 43049  0723           166          [monica and chandler's]     rachel
# 10691  0220           164  [monica and rachel's apartment]     phoebe
# 15555  0315           239                 [the restaurant]     phoebe
# 60582  1015           183               [joey's apartment]       joey
# 22169  0416           152        [monica and rachel's erm]     phoebe
# 10125  0218           110  [monica and rachel's apartment]       ross
#
#                                                 dialogue   dialogue2  \
# 40368                            (inspecting it) really?     really?
# 12453                                             crazy.      crazy.
# 6812    what?  [outside in the hallway, chandler, joe...    what?
# 35317                                              sure.       sure.
# 43049                                                hi!         hi!
# 10691                                             sure.       sure.
# 15555                                             yeah.       yeah.
# 60582                                           estelle?    estelle?
# 22169                                              yeah.       yeah.
# 10125                                           really?     really?
#
#       dialogue3 dialogue4  label_place label_str  label season  is_null  \
# 40368    really    really            0     other      0     07    False
# 12453     crazy     crazy            2      ross      2     03    False
# 6812       what      what            4    rachel      1     02    False
# 35317      sure      sure            1     other      0     06    False
# 43049        hi        hi            2    rachel      1     07    False
# 10691      sure      sure            2    phoebe      6     02    False
# 15555      yeah      yeah            6    phoebe      6     03    False
# 60582   estelle   estelle            3      joey      5     10    False
# 22169      yeah      yeah            2    phoebe      6     04    False
# 10125    really    really            2      ross      2     02    False
#
#        len_dialogue4  len_dialogue3
# 40368              1              1
# 12453              1              1
# 6812               1              1
# 35317              1              1
# 43049              1              1
# 10691              1              1
# 15555              1              1
# 60582              1              1
# 22169              1              1
# 10125              1              1

# %%
df_dlg[df_dlg['len_dialogue3']==1].label_str.value_counts()/dlg_cnt
# Out:
# chandler    0.102214
# joey        0.112402
# monica      0.110104
# other       0.135871
# phoebe      0.111423
# rachel      0.137435
# ross        0.127002
# Name: label_str, dtype: float64

# %%
df_dlg[df_dlg['len_dialogue4']==1].label_str.value_counts()/dlg_cnt
# Out:
# chandler    0.102214
# joey        0.112402
# monica      0.109984
# other       0.135223
# phoebe      0.110888
# rachel      0.137327
# ross        0.126560
# Name: label_str, dtype: float64

# %%
df_dlg['len_dialogue3'].describe()
# Out:
# count    61490.000000
# mean        10.371361
# std         10.786225
# min          0.000000
# 25%          3.000000
# 50%          7.000000
# 75%         14.000000
# max        240.000000
# Name: len_dialogue3, dtype: float64

# %%
df_dlg['len_dialogue4'].describe()
# Out:
# count    61490.000000
# mean        10.934591
# std         11.324343
# min          0.000000
# 25%          4.000000
# 50%          8.000000
# 75%         15.000000
# max        242.000000
# Name: len_dialogue4, dtype: float64

# %%
df_dlg['len_dialogue4'].plot(kind = 'hist')

# %%
sns.barplot(data = df_dlg[['label_str','len_dialogue3']], x = 'label_str', y = 'len_dialogue3')

# %%
med_len = df_dlg[['season','label_str','len_dialogue3']].groupby(['season','label_str']).median().reset_index()

# %%
plt.figure(figsize = (10,10))
sns.lineplot(data = med_len, x = 'season', y = 'len_dialogue3', hue = 'label_str')

# %%
med_len
# Out:
#    season label_str  len_dialogue3
# 0      01  chandler            8.0
# 1      01      joey            7.0
# 2      01    monica            6.0
# 3      01     other            5.0
# 4      01    phoebe            7.0
# ..    ...       ...            ...
# 65     10    monica            8.0
# 66     10     other            6.0
# 67     10    phoebe            7.0
# 68     10    rachel            7.0
# 69     10      ross            7.0
#
# [70 rows x 3 columns]

# %% [markdown]
# ## Word Cloud

# %%
def filt_word1(sent, wordlist):
    use = True
    if len(sent.split(' '))>7:
        for w in wordlist:
            if w in sent:
                use = False
                break
    return use

# %%
## World Cloud
fig, axes = plt.subplots(nrows=2, ncols=4, figsize = (25,8))

rr = 0
cc = 0
df_dlg0 = df_dlg[df_dlg['season'].isin(['01', '02', '03', '04', '05', '06', '07', '08'])]
for i in df_dlg.label_str.unique():
    text1 = ' '.join(df_dlg0[(df_dlg0.label_str==i)].dialogue4.tolist())
    wordcloud1 = WordCloud().generate(text1)
    axes[rr,cc].set_title(i)
    axes[rr,cc].imshow(wordcloud1, interpolation='bilinear')
    
    rr += 1
    
    if rr>=2:
        rr = 0
        cc += 1

wordcloud1 = WordCloud().generate('none only, none')
axes[1,3].set_title('NULL')
axes[1,3].imshow(wordcloud1, interpolation='bilinear')

# %%
en_stops = stopwords.words('english')

# %%
## top 20
df_dlg0 = df_dlg[df_dlg['season'].isin(['01', '02', '03', '04', '05', '06', '07', '08'])]
all_tp = []
for i in df_dlg.label_str.unique():
    text1 = ' '.join(df_dlg0[(df_dlg0.label_str==i)].dialogue4.tolist())
    text1_ls = pd.Series(text1.split(' '))
    text1_ls2 = text1_ls.value_counts()
    tp = list(text1_ls2[:75].keys())    
    all_tp += tp
    
all_tp = pd.Series(all_tp)
all_tp_cnt = all_tp.value_counts()

stop2 = all_tp_cnt[all_tp_cnt>=4].keys().tolist()
print(set(stop2)-set(en_stops))
# Out:
# {'gonna', 'really', 'like', 'cannot', 'would', 'okay', 'yeah', 'think', 'see', 'well', 'know', 'get', 'hey', 'uh', 'good', 'go', 'want', 'oh', 'one', 'come', 'look', 'right', 'got'}

# %%
further_stopwords = ['look', 'oh', 'one', 'come', 'gonna', 'would', 'right', 'got', 'okay', 'like', 'hey', 'uh', 'see', 'know', 'get', 'want',
                     'yeah', 'think', 'really', 'good', 'well', 'go', 'cannot'] + ['guy']

def lose_stop(sentence):
    word_list = sentence.split(' ')
    new_sen = []
    for w in word_list:
        if w not in further_stopwords:
            new_sen.append(w)
            
    return ' '.join(new_sen)

# %%
## World Cloud (more than 7) --> filter
fig, axes = plt.subplots(nrows=2, ncols=4, figsize = (25,8))

rr = 0
cc = 0
df_dlg0 = df_dlg[df_dlg['season'].isin(['01', '02', '03', '04', '05', '06', '07', '08'])]

df_dlg0['dialogue5'] = df_dlg0.dialogue4.apply(lambda x : lose_stop(x))


for i in df_dlg.label_str.unique():
    text1 = ' '.join(df_dlg0[(df_dlg0.label_str==i)].dialogue5.tolist())
    wordcloud1 = WordCloud().generate(text1)
    axes[rr,cc].set_title(i)
    axes[rr,cc].imshow(wordcloud1, interpolation='bilinear')
    
    rr += 1
    
    if rr>=2:
        rr = 0
        cc += 1

wordcloud1 = WordCloud().generate('none only, none')
axes[1,3].set_title('NULL')
axes[1,3].imshow(wordcloud1, interpolation='bilinear')
# Out:
# /Users/alamhanz/anaconda/envs/p37/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## dialogue5
df_dlg['dialogue5'] = df_dlg.dialogue4.apply(lambda x : lose_stop(x))
df_dlg.dialogue5 = df_dlg.dialogue5.fillna('')
df_dlg.dialogue5 = df_dlg.dialogue5.str.strip()
df_dlg['len_dialogue5'] = df_dlg.dialogue5.str.split().apply(lambda x : len(x))
df_dlg['is_null2'] = df_dlg['len_dialogue5']==0

# %%
XX=df_dlg['len_dialogue5']
XX.describe()
# Out:
# count    61490.000000
# mean         9.740901
# std         10.396277
# min          0.000000
# 25%          3.000000
# 50%          7.000000
# 75%         13.000000
# max        235.000000
# Name: len_dialogue5, dtype: float64

# %%
XX.plot(kind='hist')

# %%
np.percentile(XX,99)
# Out:
# 48.0

# %%
XX[XX<40].plot(kind='hist')

# %%
df_dlg2 = df_dlg[['eps','dialogue_ids','scenes_places','label_place','label_str','label','season','dialogue','dialogue5','len_dialogue5','is_null2']]

# %%
df_dlg2.groupby('label_str').is_null2.mean()
# Out:
# label_str
# chandler    0.050269
# joey        0.058708
# monica      0.046881
# other       0.048995
# phoebe      0.061396
# rachel      0.059797
# ross        0.057316
# Name: is_null2, dtype: float64

# %%
# df_dlg2 = df_dlg2[(df_dlg2['len_dialogue5']>0)&(df_dlg2['len_dialogue5']<50)][['dialogue5','label','eps','season','label_place']]
# df_dlg2.columns = ['text','label','episode','season','places']
# df_dlg2['ids'] = [i for i in range(len(df_dlg2))]

# %%
df_dlg2.head()
# Out:
#     eps  dialogue_ids   scenes_places  label_place label_str  label season  \
# 0  0101             0  [central perk]            1    monica      3     01
# 1  0101             1  [central perk]            1      joey      5     01
# 2  0101             2  [central perk]            1  chandler      4     01
# 3  0101             3  [central perk]            1    phoebe      6     01
# 4  0101             4  [central perk]            1    phoebe      6     01
#
#                                             dialogue  \
# 0    there's nothing to tell! he's just some guy ...
# 1    c'mon, you're going out with the guy! there'...
# 2     all right joey, be nice.  so does he have a...
# 3    wait, does he eat chalk? (they all stare, be...
# 4    just, 'cause, i don't want her to go through...
#
#                                            dialogue5  len_dialogue5  is_null2
# 0  there has nothing to tell he has just some i w...             12     False
# 1  on you are going out with the there has gotta ...             15     False
# 2  all joey be nice so does he have a hump a hump...             15     False
# 3                             wait does he eat chalk              5     False
# 4  just because i do not her to through what i we...             14     False

# %%
df_dlg2.shape
# Out:
# (61490, 11)

# %%
df_dlg2['ids'] = [i for i in range(len(df_dlg2))]
# Out:
# /Users/alamhanz/anaconda/envs/p37/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Spliting

# %%
df_dlg2_seen=df_dlg2[df_dlg2['season'].isin(['01', '02', '03', '04', '05', '06', '07', '08'])]
train_ids = df_dlg2_seen.sample(int(len(df_dlg2_seen)*0.75),random_state = 167).ids.tolist()
df_dlg2_seen['is_train'] = df_dlg2_seen.ids.isin(train_ids)
df_dlg2_unseen=df_dlg2[df_dlg2['season'].isin(['09', '10'])]
# Out:
# /Users/alamhanz/anaconda/envs/p37/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(train_ids)
# Out:
# 37232

# %%
df_dlg2_seen['is_train'].mean()
# Out:
# 0.7499949640432689

# %%
df_dlg2_seen.head(10)
# Out:
#     eps  dialogue_ids   scenes_places  label_place label_str  label season  \
# 0  0101             0  [central perk]            1    monica      3     01
# 1  0101             1  [central perk]            1      joey      5     01
# 2  0101             2  [central perk]            1  chandler      4     01
# 3  0101             3  [central perk]            1    phoebe      6     01
# 4  0101             4  [central perk]            1    phoebe      6     01
# 5  0101             5  [central perk]            1    monica      3     01
# 6  0101             6  [central perk]            1  chandler      4     01
# 7  0101             7  [central perk]            1  chandler      4     01
# 8  0101             8  [central perk]            1     other      0     01
# 9  0101             9  [central perk]            1  chandler      4     01
#
#                                             dialogue  \
# 0    there's nothing to tell! he's just some guy ...
# 1    c'mon, you're going out with the guy! there'...
# 2     all right joey, be nice.  so does he have a...
# 3    wait, does he eat chalk? (they all stare, be...
# 4    just, 'cause, i don't want her to go through...
# 5    okay, everybody relax. this is not even a da...
# 6             sounds like a date to me. [time lapse]
# 7    alright, so i'm back in high school, i'm sta...
# 8                          oh, yeah. had that dream.
# 9    then i look down, and i realize there's a ph...
#
#                                            dialogue5  len_dialogue5  is_null2  \
# 0  there has nothing to tell he has just some i w...             12     False
# 1  on you are going out with the there has gotta ...             15     False
# 2  all joey be nice so does he have a hump a hump...             15     False
# 3                             wait does he eat chalk              5     False
# 4  just because i do not her to through what i we...             14     False
# 5  everybody relax this is not even a date it has...             21     False
# 6                                sounds a date to me              5     False
# 7  alright so i am back in high school i am stand...             24     False
# 8                                     had that dream              3     False
# 9  then i down and i realize there has a phone there             11     False
#
#    ids  is_train
# 0    0      True
# 1    1     False
# 2    2      True
# 3    3     False
# 4    4      True
# 5    5      True
# 6    6      True
# 7    7      True
# 8    8      True
# 9    9     False

# %%
df_dlg2_unseen.head()
# Out:
#         eps  dialogue_ids    scenes_places  label_place label_str  label  \
# 49643  0901             0  [rachel's room]            2    rachel      1
# 49644  0901             1  [rachel's room]            2    rachel      1
# 49645  0901             2  [rachel's room]            2    rachel      1
# 49646  0901             3  [rachel's room]            2      joey      5
# 49647  0901             4  [rachel's room]            2      ross      2
#
#       season                                           dialogue  \
# 49643     09    joey. (he turns to face rachel on one knee w...
# 49644     09    (seeing the ring) oh my god. (pause) okay. (...
# 49645     09    so uh...i guess we should...make it official...
# 49646     09    uh... look rach...(ross enters.) hey ross is...
# 49647     09                     hey joey. (to rachel) hey you.
#
#                                           dialogue5  len_dialogue5  is_null2  \
# 49643                                          joey              1     False
# 49644                                        my god              2     False
# 49645     so i guess we should make it official huh              9     False
# 49646  rach ross is here it has my friend ross ross             10     False
# 49647                                      joey you              2     False
#
#          ids
# 49643  49643
# 49644  49644
# 49645  49645
# 49646  49646
# 49647  49647

# %% [markdown]
# ## Second Dataset

# %%
df_dlg2_seen2 = df_dlg2_seen.copy()
df_dlg2_seen2.rename(columns = {'dialogue5':'text2'},inplace = True)
df_dlg2_seen2['text1'] = df_dlg2_seen2.groupby(['eps'])['text2'].shift(1)
df_dlg2_seen2['label_prev'] = df_dlg2_seen2.groupby(['eps'])['label'].shift(1)
df_dlg2_seen2['label_str_prev'] = df_dlg2_seen2.groupby(['eps'])['label_str'].shift(1)

df_dlg2_seen2 = df_dlg2_seen2[df_dlg2_seen2['label']!=df_dlg2_seen2['label_prev']] 
df_dlg2_seen2
# Out:
#         eps  dialogue_ids        scenes_places  label_place label_str  label  \
# 0      0101             0       [central perk]            1    monica      3
# 1      0101             1       [central perk]            1      joey      5
# 2      0101             2       [central perk]            1  chandler      4
# 3      0101             3       [central perk]            1    phoebe      6
# 5      0101             5       [central perk]            1    monica      3
# ...     ...           ...                  ...          ...       ...    ...
# 49637  0823           524  [the delivery room]            8      joey      5
# 49638  0823           525  [the delivery room]            8    rachel      1
# 49639  0823           526  [the delivery room]            8      joey      5
# 49640  0823           527  [the delivery room]            8    rachel      1
# 49642  0823           529  [the delivery room]            8     other      0
#
#       season                                           dialogue  \
# 0         01    there's nothing to tell! he's just some guy ...
# 1         01    c'mon, you're going out with the guy! there'...
# 2         01     all right joey, be nice.  so does he have a...
# 3         01    wait, does he eat chalk? (they all stare, be...
# 5         01    okay, everybody relax. this is not even a da...
# ...      ...                                                ...
# 49637     08                                              sure.
# 49638     08    okay. (he moves ross's coat to get the tissu...
# 49639     08                                            my god.
# 49640     08    joey. (he turns to face rachel on one knee w...
# 49642     08   as with all the cliffhangers, there was no cr...
#
#                                                    text2  len_dialogue5  \
# 0      there has nothing to tell he has just some i w...             12
# 1      on you are going out with the there has gotta ...             15
# 2      all joey be nice so does he have a hump a hump...             15
# 3                                 wait does he eat chalk              5
# 5      everybody relax this is not even a date it has...             21
# ...                                                  ...            ...
# 49637                                               sure              1
# 49638                                                                 0
# 49639                                             my god              2
# 49640                                               joey              1
# 49642  as with all the cliffhangers there was no cred...             31
#
#        is_null2    ids  is_train  \
# 0         False      0      True
# 1         False      1     False
# 2         False      2      True
# 3         False      3     False
# 5         False      5      True
# ...         ...    ...       ...
# 49637     False  49637      True
# 49638      True  49638      True
# 49639     False  49639     False
# 49640     False  49640     False
# 49642     False  49642     False
#
#                                                    text1  label_prev  \
# 0                                                    NaN         NaN
# 1      there has nothing to tell he has just some i w...         3.0
# 2      on you are going out with the there has gotta ...         5.0
# 3      all joey be nice so does he have a hump a hump...         4.0
# 5      just because i do not her to through what i we...         6.0
# ...                                                  ...         ...
# 49637  hon can you grab me my other box of tissues th...         1.0
# 49638                                               sure         5.0
# 49639                                                            1.0
# 49640                                             my god         5.0
# 49642                             my god closing credits         1.0
#
#       label_str_prev
# 0                NaN
# 1             monica
# 2               joey
# 3           chandler
# 5             phoebe
# ...              ...
# 49637         rachel
# 49638           joey
# 49639         rachel
# 49640           joey
# 49642         rachel
#
# [47802 rows x 16 columns]

# %%
df_dlg2_seen2['label'].value_counts()
# Out:
# 0    7549
# 1    7464
# 2    7143
# 3    6708
# 4    6620
# 5    6442
# 6    5876
# Name: label, dtype: int64

# %%
df_dlg2_unseen2 = df_dlg2_unseen.copy()
df_dlg2_unseen2.rename(columns = {'dialogue5':'text2'},inplace = True)
df_dlg2_unseen2['text1'] = df_dlg2_unseen2.groupby(['eps'])['text2'].shift(1)
df_dlg2_unseen2['label_prev'] = df_dlg2_unseen2.groupby(['eps'])['label'].shift(1)
df_dlg2_unseen2['label_str_prev'] = df_dlg2_unseen2.groupby(['eps'])['label_str'].shift(1)

df_dlg2_unseen2 = df_dlg2_unseen2[df_dlg2_unseen2['label']!=df_dlg2_unseen2['label_prev']] 
df_dlg2_unseen2
# Out:
#              eps  dialogue_ids                      scenes_places  \
# 49643       0901             0                    [rachel's room]
# 49646       0901             3                    [rachel's room]
# 49647       0901             4                    [rachel's room]
# 49648       0901             5                    [rachel's room]
# 49649       0901             6                    [rachel's room]
# ...          ...           ...                                ...
# 61485  1017-1018           580  [monica and chandler's apartment]
# 61486  1017-1018           581  [monica and chandler's apartment]
# 61487  1017-1018           582  [monica and chandler's apartment]
# 61488  1017-1018           583  [monica and chandler's apartment]
# 61489  1017-1018           584  [monica and chandler's apartment]
#
#        label_place label_str  label season  \
# 49643            2    rachel      1     09
# 49646            2      joey      5     09
# 49647            2      ross      2     09
# 49648            2    rachel      1     09
# 49649            2      joey      5     09
# ...            ...       ...    ...    ...
# 61485            2  chandler      4     10
# 61486            2    rachel      1     10
# 61487            2    monica      3     10
# 61488            2    rachel      1     10
# 61489            2  chandler      4     10
#
#                                                 dialogue  \
# 49643    joey. (he turns to face rachel on one knee w...
# 49646    uh... look rach...(ross enters.) hey ross is...
# 49647                     hey joey. (to rachel) hey you.
# 49648                                           hey you.
# 49649    hey and look he brought flowers. thanks ross...
# ...                                                  ...
# 61485   oh, it's gonna be okay. (chandler hugs her. m...
# 61486   (crying) do you guys have to go to the new ho...
# 61487                                  we got some time.
# 61488                   okay, should we get some coffee?
# 61489   sure. where? (they all leave the apartment. j...
#
#                                                    text2  len_dialogue5  \
# 49643                                               joey              1
# 49646       rach ross is here it has my friend ross ross             10
# 49647                                           joey you              2
# 49648                                                you              1
# 49649  and he brought flowers thanks ross but i am mo...             13
# ...                                                  ...            ...
# 61485                                          it has be              3
# 61486  do you guys have to to the new house away or d...             16
# 61487                                       we some time              3
# 61488                              should we some coffee              4
# 61489                                 sure where the end              4
#
#        is_null2    ids                                              text1  \
# 49643     False  49643                                                NaN
# 49646     False  49646          so i guess we should make it official huh
# 49647     False  49647       rach ross is here it has my friend ross ross
# 49648     False  49648                                           joey you
# 49649     False  49649                                                you
# ...         ...    ...                                                ...
# 61485     False  61485                this is harder than i thought it be
# 61486     False  61486                                          it has be
# 61487     False  61487  do you guys have to to the new house away or d...
# 61488     False  61488                                       we some time
# 61489     False  61489                              should we some coffee
#
#        label_prev label_str_prev
# 49643         NaN            NaN
# 49646         1.0         rachel
# 49647         5.0           joey
# 49648         2.0           ross
# 49649         1.0         rachel
# ...           ...            ...
# 61485         3.0         monica
# 61486         4.0       chandler
# 61487         1.0         rachel
# 61488         3.0         monica
# 61489         1.0         rachel
#
# [11301 rows x 15 columns]

# %% [markdown]
# ## Saving

# %%
df_dlg2_seen.to_csv('../data/friends_seen_season_new.csv',index=False)
df_dlg2_unseen.to_csv('../data/friends_unseen_season_new.csv',index=False)

df_dlg2_seen2.to_csv('../data/friends_seen_season2_new.csv',index=False)
df_dlg2_unseen2.to_csv('../data/friends_unseen_season2_new.csv',index=False)

# %% [markdown]
# ## TF-IDF similarity

# %%
df_dlg2_seen
# Out:
#         eps  dialogue_ids        scenes_places  label_place label_str  label  \
# 0      0101             0       [central perk]            1    monica      3
# 1      0101             1       [central perk]            1      joey      5
# 2      0101             2       [central perk]            1  chandler      4
# 3      0101             3       [central perk]            1    phoebe      6
# 4      0101             4       [central perk]            1    phoebe      6
# ...     ...           ...                  ...          ...       ...    ...
# 49638  0823           525  [the delivery room]            8    rachel      1
# 49639  0823           526  [the delivery room]            8      joey      5
# 49640  0823           527  [the delivery room]            8    rachel      1
# 49641  0823           528  [the delivery room]            8    rachel      1
# 49642  0823           529  [the delivery room]            8     other      0
#
#       season                                           dialogue  \
# 0         01    there's nothing to tell! he's just some guy ...
# 1         01    c'mon, you're going out with the guy! there'...
# 2         01     all right joey, be nice.  so does he have a...
# 3         01    wait, does he eat chalk? (they all stare, be...
# 4         01    just, 'cause, i don't want her to go through...
# ...      ...                                                ...
# 49638     08    okay. (he moves ross's coat to get the tissu...
# 49639     08                                            my god.
# 49640     08    joey. (he turns to face rachel on one knee w...
# 49641     08    (seeing the ring) oh my god. (pause) okay. (...
# 49642     08   as with all the cliffhangers, there was no cr...
#
#                                                dialogue5  len_dialogue5  \
# 0      there has nothing to tell he has just some i w...             12
# 1      on you are going out with the there has gotta ...             15
# 2      all joey be nice so does he have a hump a hump...             15
# 3                                 wait does he eat chalk              5
# 4      just because i do not her to through what i we...             14
# ...                                                  ...            ...
# 49638                                                                 0
# 49639                                             my god              2
# 49640                                               joey              1
# 49641                             my god closing credits              4
# 49642  as with all the cliffhangers there was no cred...             31
#
#        is_null2  is_train
# 0         False      True
# 1         False      True
# 2         False      True
# 3         False      True
# 4         False      True
# ...         ...       ...
# 49638      True      True
# 49639     False      True
# 49640     False      True
# 49641     False      True
# 49642     False      True
#
# [49643 rows x 12 columns]

# %%
corpus = df_dlg2_seen['dialogue5'].tolist()
vectorizer = TfidfVectorizer(min_df = 0.1, max_features = 100)
vectorizer.fit(corpus)
# Out:
# TfidfVectorizer(max_features=100, min_df=0.1)

# %%
df1 = df_dlg2_seen[df_dlg2_seen.label_str == 'monica'].sample(5)
V_M = vectorizer.transform(df1['dialogue5']).toarray()

df0 = df_dlg2_seen[df_dlg2_seen.label_str == 'joey'].sample(5)
V_J = vectorizer.transform(df0['dialogue5']).toarray()

# %%
distance_matrix(V_M, V_J)
# Out:
# array([[0.        , 1.        , 1.        , 0.        , 1.        ],
#        [1.        , 1.41421356, 1.41421356, 1.        , 1.41421356],
#        [1.        , 0.        , 1.41421356, 1.        , 0.93759418],
#        [1.        , 1.41421356, 0.83148796, 1.        , 0.65876204],
#        [1.        , 1.41421356, 1.41421356, 1.        , 1.41421356]])

# %%
distance_matrix([V_M[3]],[V_J[2]])
# Out:
# array([[0.83148796]])

# %%
df1['dialogue5'].iloc[3]
# Out:
# 'no it has not it has second'

# %%
df0['dialogue5'].iloc[2]
# Out:
# 'phoebs check it out check it out check it out check it out'

# %% [markdown]
# ## Who Talk Places

# %%
WTP = df_dlg2_seen.groupby(['label_place','label_str']).size().unstack()
WTP2 = (WTP.transpose() / WTP.sum(axis = 1)).fillna(0).transpose()

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(WTP2, annot=True, fmt=".2%", linewidths=.2, cmap="mako")

# %% [markdown]
# ## Who talk Who

# %%
df_dlg2_seen2.head()
# Out:
#     eps  dialogue_ids   scenes_places  label_place label_str  label season  \
# 0  0101             0  [central perk]            1    monica      3     01
# 1  0101             1  [central perk]            1      joey      5     01
# 2  0101             2  [central perk]            1  chandler      4     01
# 3  0101             3  [central perk]            1    phoebe      6     01
# 5  0101             5  [central perk]            1    monica      3     01
#
#                                             dialogue  \
# 0    there's nothing to tell! he's just some guy ...
# 1    c'mon, you're going out with the guy! there'...
# 2     all right joey, be nice.  so does he have a...
# 3    wait, does he eat chalk? (they all stare, be...
# 5    okay, everybody relax. this is not even a da...
#
#                                                text2  len_dialogue5  is_null2  \
# 0  there has nothing to tell he has just some i w...             12     False
# 1  on you are going out with the there has gotta ...             15     False
# 2  all joey be nice so does he have a hump a hump...             15     False
# 3                             wait does he eat chalk              5     False
# 5  everybody relax this is not even a date it has...             21     False
#
#    is_train                                              text1  label_prev  \
# 0      True                                                NaN         NaN
# 1      True  there has nothing to tell he has just some i w...         3.0
# 2      True  on you are going out with the there has gotta ...         5.0
# 3      True  all joey be nice so does he have a hump a hump...         4.0
# 5      True  just because i do not her to through what i we...         6.0
#
#   label_str_prev
# 0            NaN
# 1         monica
# 2           joey
# 3       chandler
# 5         phoebe

# %%
def rearrange(x):
    if type(x) == str:
        x0 = x.split('_')
        x0.sort()
        return '_'.join(x0)
    else:
        return None

# %%
df_dlg2_seen2['connect'] = (df_dlg2_seen2['label_str_prev']+"_"+df_dlg2_seen2['label_str']).apply(rearrange)

# %%
WTW = df_dlg2_seen2.groupby(['connect','season']).size().unstack()
WTW2 = (WTW / WTW.sum(axis = 0)).fillna(0)
# WTW2

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(WTW2, annot=True, fmt=".2%", linewidths=.2, cmap="mako")

# %%
WTO = df_dlg2_seen2[df_dlg2_seen2.label_prev == 0].groupby(['label_str','season']).size().unstack()
WTO2 = (WTO / WTO.sum(axis = 0)).fillna(0)

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(WTO2, annot=True, fmt=".2%", linewidths=.2, cmap="mako")
